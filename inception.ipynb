# %% [markdown]
# # Import Modules

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# VGG16
from keras.applications.vgg16 import VGG16

# To show images
from PIL import Image
print("status ok")
# Out:
# status ok

# %% [markdown]
# # Create Functions

# %% [markdown]
# #### Creates data frame

# %%
# Collect all data into one dataframe
def create_df(dataset, sample_size):
    image_paths, labels = [], []

    for dirpath, dirnames, filenames in os.walk(dataset):
        for i, filename in enumerate(filenames):
            if i >= sample_size:
                break
            
            image = os.path.join(dirpath, filename)
            image_paths.append(image)
            if dirpath[-3:] == 'all':
                labels.append('all')
            else:
                labels.append('hem')

    df = pd.DataFrame({'Image Path': image_paths, 
                       'Label': labels})
    
    return df

train_dir = "C-NMC_Leukemia/training_data"
df = create_df(train_dir, 500)

train_df, remaining_df = train_test_split(df, train_size=0.7, shuffle=True, random_state=31, stratify=df['Label'])
valid_df, test_df = train_test_split(remaining_df, train_size=0.5, shuffle=True, random_state=31, stratify=remaining_df['Label'])

print("Number of training samples: %d" % len(train_df.index))
print("Number of test samples: %d" % len(test_df.index))  
print("Number of validation samples: %d" % len(valid_df.index))
# Out:
# Number of training samples: 2100
# Number of test samples: 450
# Number of validation samples: 450

# %% [markdown]
# #### Display Model Performance

# %%
def show_history_plot(history):

    training_accuracy = history['accuracy']
    epochs = range(1, len(training_accuracy) + 1)

    # Creating subplots for accuracy and loss
    plt.figure(figsize=(15, 5))

    # Plotting training and validation accuracy
    plt.subplot(1, 2, 1)  # 1 row, 2 columns, first plot
    plt.plot(epochs, history['accuracy'], 'b', label='Training accuracy', marker='o')
    plt.plot(epochs, history['val_accuracy'], 'c', label='Validation accuracy', marker='o')
    plt.title('Training and Validation Accuracy', fontsize=14)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend()
    plt.grid(True)

    # Plotting training and validation loss
    plt.subplot(1, 2, 2)  # 1 row, 2 columns, second plot
    plt.plot(epochs, history['loss'], 'b', label='Training loss', marker='o')
    plt.plot(epochs, history['val_loss'], 'c', label='Validation loss', marker='o')
    plt.title('Training and Validation Loss', fontsize=14)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend()
    plt.grid(True)

    # Improve layout and displaying the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Confusion Matrix

# %%
def show_conf_matrix(model):
    test_gen.reset()  # Reset the generator to be sure it's at the start of the dataset
    y_pred = model.predict(test_gen, steps=test_gen.n // test_gen.batch_size+1, verbose=0)

    label_dict = test_gen.class_indices
    classes = list(label_dict.keys())

    # Convert predictions to labels
    pred_labels = np.argmax(y_pred, axis=1)  
    y_true = test_gen.classes  
    
    # Generate the confusion matrix
    confusion_matrix = metrics.confusion_matrix(y_true, pred_labels)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[False, True])

    # Plot the confusion matrix 
    cmap = plt.cm.Blues
    cm_display.plot(cmap=cmap, colorbar=False)  
    
    plt.title('Confusion Matrix', fontsize=16)
    plt.figure(figsize=(7, 7)) 
    plt.show()

# %% [markdown]
# #### Evaluation Matrix

# %%
def evaluation_matrix(model):
    test_steps = len(test_df) // batch_size
    train_score = model.evaluate(train_gen, steps= test_steps, verbose= 0)
    valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 0)
    test_score = model.evaluate(test_gen, steps= test_steps, verbose= 0)

    header = "{:<12} {:<10} {:<10}".format("", "Loss", "Accuracy") 
    separator = '-' * len(header)
    train_row = "{:<12} {:<10.5f} {:<10.5f}".format("Train", train_score[0], train_score[1])  # Formats the float to five decimal places
    valid_row = "{:<12} {:<10.5f} {:<10.5f}".format("Validation", valid_score[0], valid_score[1])
    test_row = "{:<12} {:<10.5f} {:<10.5f}".format("Test", test_score[0], test_score[1])

    table = '\n'.join([header, separator, train_row, valid_row, test_row])
    print(table)

# %% [markdown]
# #### Show Images

# %%
hem_img = train_df[train_df['Label'] == 'hem'].sample(3)
all_img = train_df[train_df['Label'] == 'all'].sample(3)
sampled_df = pd.concat([hem_img, all_img])

# Create a figure with subplots to show the images in
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 6))

for i, row in enumerate(sampled_df.iterrows()):
    img = mpimg.imread(row[1]['Image Path'])
    ax = axes[i//3, i%3]
    ax.imshow(img)
    ax.axis('off')    
    if row[1]['Label'] == 'hem':
        ax.set_title(f"Label: hem")
    else:
        ax.set_title(f"Label: all")

plt.show()

# %% [markdown]
# #### Initializing Image Data Generators

# %%
batch_size = 40

train_data_generator = ImageDataGenerator(horizontal_flip=True)
valid_data_generator = ImageDataGenerator()

train_gen = train_data_generator.flow_from_dataframe( train_df, x_col= 'Image Path', y_col= 'Label', target_size= (224, 224), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

valid_gen = valid_data_generator.flow_from_dataframe( valid_df, x_col= 'Image Path', y_col= 'Label', target_size= (224, 224), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

test_gen = valid_data_generator.flow_from_dataframe( test_df, x_col= 'Image Path', y_col= 'Label', target_size= (224, 224), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= batch_size)

train_steps = test_gen.n // test_gen.batch_size + 1
validation_steps = valid_gen.n // valid_gen.batch_size
# Out:
# Found 2100 validated image filenames belonging to 2 classes.
# Found 450 validated image filenames belonging to 2 classes.
# Found 450 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Classification Models

# %% [markdown]
# ## VGG16

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras.applications import InceptionV3

# Instantiate base model
img_shape = (224, 224, 3)
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=img_shape, pooling=None)

# Freeze base model to keep pre-trained weights
base_model.trainable = False

# Add custom top layers for binary classification
last_layer = base_model.get_layer('mixed7')  # Example layer name from InceptionV3
last_output = last_layer.output
x = tf.keras.layers.GlobalMaxPooling2D()(last_output)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(2, activation='sigmoid')(x)  # Binary classification, so 2 units with sigmoid activation

# Create new model
Inception_model = tf.keras.Model(base_model.input, x, name="InceptionV3")

Inception_model.compile(
    optimizer=Adamax(learning_rate=0.001),
    loss='binary_crossentropy',  # Use 'binary_crossentropy' for binary classification
    metrics=['accuracy', Recall(name='recall'), Precision(name='precision')]
)

Inception_model.summary()
# Out:
# Model: "InceptionV3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_188 (Conv2D)         (None, 111, 111, 32)         864       ['input_3[0][0]']
#
#  batch_normalization_188 (B  (None, 111, 111, 32)         96        ['conv2d_188[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_189 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_188[0][0]']
#
#  batch_normalization_189 (B  (None, 109, 109, 32)         96        ['conv2d_189[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_190 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_189[0][0]']
#
#  batch_normalization_190 (B  (None, 109, 109, 64)         192       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_190 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 54, 54, 64)           0         ['activation_190[0][0]']
#  g2D)
#
#  conv2d_191 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (B  (None, 54, 54, 80)           240       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  conv2d_192 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_191[0][0]']
#
#  batch_normalization_192 (B  (None, 52, 52, 192)          576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 25, 25, 192)          0         ['activation_192[0][0]']
#  g2D)
#
#  conv2d_196 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (B  (None, 25, 25, 64)           192       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_194 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_196[0][0]']
#
#  batch_normalization_194 (B  (None, 25, 25, 48)           144       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  batch_normalization_197 (B  (None, 25, 25, 96)           288       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_194 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  activation_197 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  average_pooling2d_18 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_9[0][0]']
#  agePooling2D)
#
#  conv2d_193 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_197[0][0]']
#
#  conv2d_199 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (B  (None, 25, 25, 64)           192       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  batch_normalization_195 (B  (None, 25, 25, 64)           192       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 25, 25, 96)           288       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  batch_normalization_199 (B  (None, 25, 25, 32)           96        ['conv2d_199[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  activation_195 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  activation_199 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_193[0][0]',
#                                                                      'activation_195[0][0]',
#                                                                      'activation_198[0][0]',
#                                                                      'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_203 (B  (None, 25, 25, 64)           192       ['conv2d_203[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_203[0][0]']
#
#  batch_normalization_201 (B  (None, 25, 25, 48)           144       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_204 (B  (None, 25, 25, 96)           288       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  activation_204 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  average_pooling2d_19 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_200 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (B  (None, 25, 25, 64)           192       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 25, 25, 64)           192       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  batch_normalization_205 (B  (None, 25, 25, 96)           288       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  batch_normalization_206 (B  (None, 25, 25, 64)           192       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  activation_205 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  activation_206 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_200[0][0]',
#                                                                      'activation_202[0][0]',
#                                                                      'activation_205[0][0]',
#                                                                      'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_210 (B  (None, 25, 25, 64)           192       ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_210[0][0]']
#
#  batch_normalization_208 (B  (None, 25, 25, 48)           144       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  batch_normalization_211 (B  (None, 25, 25, 96)           288       ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  activation_211 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  average_pooling2d_20 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_207 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (B  (None, 25, 25, 64)           192       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  batch_normalization_209 (B  (None, 25, 25, 64)           192       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  batch_normalization_212 (B  (None, 25, 25, 96)           288       ['conv2d_212[0][0]']
#  atchNormalization)
#
#  batch_normalization_213 (B  (None, 25, 25, 64)           192       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  activation_209 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  activation_212 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  activation_213 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_213[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_207[0][0]',
#                                                                      'activation_209[0][0]',
#                                                                      'activation_212[0][0]',
#                                                                      'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_215 (B  (None, 25, 25, 64)           192       ['conv2d_215[0][0]']
#  atchNormalization)
#
#  activation_215 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  conv2d_216 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_215[0][0]']
#
#  batch_normalization_216 (B  (None, 25, 25, 96)           288       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  conv2d_214 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_216[0][0]']
#
#  batch_normalization_214 (B  (None, 12, 12, 384)          1152      ['conv2d_214[0][0]']
#  atchNormalization)
#
#  batch_normalization_217 (B  (None, 12, 12, 96)           288       ['conv2d_217[0][0]']
#  atchNormalization)
#
#  activation_214 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  activation_217 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  max_pooling2d_10 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_214[0][0]',
#                                                                      'activation_217[0][0]',
#                                                                      'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_222 (B  (None, 12, 12, 128)          384       ['conv2d_222[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_223 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_222[0][0]']
#
#  batch_normalization_223 (B  (None, 12, 12, 128)          384       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  activation_223 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv2d_219 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_223[0][0]']
#
#  batch_normalization_219 (B  (None, 12, 12, 128)          384       ['conv2d_219[0][0]']
#  atchNormalization)
#
#  batch_normalization_224 (B  (None, 12, 12, 128)          384       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_219[0][0
#  )                                                                  ]']
#
#  activation_224 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_220 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_224[0][0]']
#
#  batch_normalization_220 (B  (None, 12, 12, 128)          384       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  batch_normalization_225 (B  (None, 12, 12, 128)          384       ['conv2d_225[0][0]']
#  atchNormalization)
#
#  activation_220 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  activation_225 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  average_pooling2d_21 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_218 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (B  (None, 12, 12, 192)          576       ['conv2d_218[0][0]']
#  atchNormalization)
#
#  batch_normalization_221 (B  (None, 12, 12, 192)          576       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  batch_normalization_226 (B  (None, 12, 12, 192)          576       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  batch_normalization_227 (B  (None, 12, 12, 192)          576       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  activation_221 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  activation_226 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  activation_227 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_218[0][0]',
#                                                                      'activation_221[0][0]',
#                                                                      'activation_226[0][0]',
#                                                                      'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_232 (B  (None, 12, 12, 160)          480       ['conv2d_232[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv2d_233 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_232[0][0]']
#
#  batch_normalization_233 (B  (None, 12, 12, 160)          480       ['conv2d_233[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_229 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_233[0][0]']
#
#  batch_normalization_229 (B  (None, 12, 12, 160)          480       ['conv2d_229[0][0]']
#  atchNormalization)
#
#  batch_normalization_234 (B  (None, 12, 12, 160)          480       ['conv2d_234[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  activation_234 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_230 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_234[0][0]']
#
#  batch_normalization_230 (B  (None, 12, 12, 160)          480       ['conv2d_230[0][0]']
#  atchNormalization)
#
#  batch_normalization_235 (B  (None, 12, 12, 160)          480       ['conv2d_235[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  activation_235 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  average_pooling2d_22 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_228 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (B  (None, 12, 12, 192)          576       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  batch_normalization_231 (B  (None, 12, 12, 192)          576       ['conv2d_231[0][0]']
#  atchNormalization)
#
#  batch_normalization_236 (B  (None, 12, 12, 192)          576       ['conv2d_236[0][0]']
#  atchNormalization)
#
#  batch_normalization_237 (B  (None, 12, 12, 192)          576       ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  activation_231 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  activation_236 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  activation_237 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_228[0][0]',
#                                                                      'activation_231[0][0]',
#                                                                      'activation_236[0][0]',
#                                                                      'activation_237[0][0]']
#
#  conv2d_242 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_242 (B  (None, 12, 12, 160)          480       ['conv2d_242[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_242[0][0]']
#
#  batch_normalization_243 (B  (None, 12, 12, 160)          480       ['conv2d_243[0][0]']
#  atchNormalization)
#
#  activation_243 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_239 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_243[0][0]']
#
#  batch_normalization_239 (B  (None, 12, 12, 160)          480       ['conv2d_239[0][0]']
#  atchNormalization)
#
#  batch_normalization_244 (B  (None, 12, 12, 160)          480       ['conv2d_244[0][0]']
#  atchNormalization)
#
#  activation_239 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_239[0][0
#  )                                                                  ]']
#
#  activation_244 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_244[0][0
#  )                                                                  ]']
#
#  conv2d_240 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_239[0][0]']
#
#  conv2d_245 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_244[0][0]']
#
#  batch_normalization_240 (B  (None, 12, 12, 160)          480       ['conv2d_240[0][0]']
#  atchNormalization)
#
#  batch_normalization_245 (B  (None, 12, 12, 160)          480       ['conv2d_245[0][0]']
#  atchNormalization)
#
#  activation_240 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  activation_245 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_245[0][0
#  )                                                                  ]']
#
#  average_pooling2d_23 (Aver  (None, 12, 12, 768)          0         ['mixed5[0][0]']
#  agePooling2D)
#
#  conv2d_238 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed5[0][0]']
#
#  conv2d_241 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_240[0][0]']
#
#  conv2d_246 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_245[0][0]']
#
#  conv2d_247 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_23[0][0]']
#
#  batch_normalization_238 (B  (None, 12, 12, 192)          576       ['conv2d_238[0][0]']
#  atchNormalization)
#
#  batch_normalization_241 (B  (None, 12, 12, 192)          576       ['conv2d_241[0][0]']
#  atchNormalization)
#
#  batch_normalization_246 (B  (None, 12, 12, 192)          576       ['conv2d_246[0][0]']
#  atchNormalization)
#
#  batch_normalization_247 (B  (None, 12, 12, 192)          576       ['conv2d_247[0][0]']
#  atchNormalization)
#
#  activation_238 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_238[0][0
#  )                                                                  ]']
#
#  activation_241 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_241[0][0
#  )                                                                  ]']
#
#  activation_246 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  activation_247 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_247[0][0
#  )                                                                  ]']
#
#  mixed6 (Concatenate)        (None, 12, 12, 768)          0         ['activation_238[0][0]',
#                                                                      'activation_241[0][0]',
#                                                                      'activation_246[0][0]',
#                                                                      'activation_247[0][0]']
#
#  conv2d_252 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed6[0][0]']
#
#  batch_normalization_252 (B  (None, 12, 12, 192)          576       ['conv2d_252[0][0]']
#  atchNormalization)
#
#  activation_252 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_252[0][0
#  )                                                                  ]']
#
#  conv2d_253 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_252[0][0]']
#
#  batch_normalization_253 (B  (None, 12, 12, 192)          576       ['conv2d_253[0][0]']
#  atchNormalization)
#
#  activation_253 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_253[0][0
#  )                                                                  ]']
#
#  conv2d_249 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed6[0][0]']
#
#  conv2d_254 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_253[0][0]']
#
#  batch_normalization_249 (B  (None, 12, 12, 192)          576       ['conv2d_249[0][0]']
#  atchNormalization)
#
#  batch_normalization_254 (B  (None, 12, 12, 192)          576       ['conv2d_254[0][0]']
#  atchNormalization)
#
#  activation_249 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_249[0][0
#  )                                                                  ]']
#
#  activation_254 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_254[0][0
#  )                                                                  ]']
#
#  conv2d_250 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_249[0][0]']
#
#  conv2d_255 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_254[0][0]']
#
#  batch_normalization_250 (B  (None, 12, 12, 192)          576       ['conv2d_250[0][0]']
#  atchNormalization)
#
#  batch_normalization_255 (B  (None, 12, 12, 192)          576       ['conv2d_255[0][0]']
#  atchNormalization)
#
#  activation_250 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_250[0][0
#  )                                                                  ]']
#
#  activation_255 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_255[0][0
#  )                                                                  ]']
#
#  average_pooling2d_24 (Aver  (None, 12, 12, 768)          0         ['mixed6[0][0]']
#  agePooling2D)
#
#  conv2d_248 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed6[0][0]']
#
#  conv2d_251 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_250[0][0]']
#
#  conv2d_256 (Conv2D)         (None, 12, 12, 192)          258048    ['activation_255[0][0]']
#
#  conv2d_257 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_24[0][0]']
#
#  batch_normalization_248 (B  (None, 12, 12, 192)          576       ['conv2d_248[0][0]']
#  atchNormalization)
#
#  batch_normalization_251 (B  (None, 12, 12, 192)          576       ['conv2d_251[0][0]']
#  atchNormalization)
#
#  batch_normalization_256 (B  (None, 12, 12, 192)          576       ['conv2d_256[0][0]']
#  atchNormalization)
#
#  batch_normalization_257 (B  (None, 12, 12, 192)          576       ['conv2d_257[0][0]']
#  atchNormalization)
#
#  activation_248 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_248[0][0
#  )                                                                  ]']
#
#  activation_251 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_251[0][0
#  )                                                                  ]']
#
#  activation_256 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_256[0][0
#  )                                                                  ]']
#
#  activation_257 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_257[0][0
#  )                                                                  ]']
#
#  mixed7 (Concatenate)        (None, 12, 12, 768)          0         ['activation_248[0][0]',
#                                                                      'activation_251[0][0]',
#                                                                      'activation_256[0][0]',
#                                                                      'activation_257[0][0]']
#
#  global_max_pooling2d_1 (Gl  (None, 768)                  0         ['mixed7[0][0]']
#  obalMaxPooling2D)
#
#  dropout_1 (Dropout)         (None, 768)                  0         ['global_max_pooling2d_1[0][0]
#                                                                     ']
#
#  dense_1 (Dense)             (None, 2)                    1538      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8976802 (34.24 MB)
# Trainable params: 1538 (6.01 KB)
# Non-trainable params: 8975264 (34.24 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# #### Train Model

# %%
epochs = 15

history_Inception = Inception_model.fit(
    train_gen,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=validation_steps,
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 28s 2s/step - loss: 9.1879 - accuracy: 0.4891 - recall: 0.3696 - precision: 0.4899 - val_loss: 1.8679 - val_accuracy: 0.6045 - val_recall: 0.7045 - val_precision: 0.5496
# Epoch 2/15
# 12/12 [==============================] - 18s 2s/step - loss: 6.6591 - accuracy: 0.5562 - recall: 0.5833 - precision: 0.5263 - val_loss: 1.6446 - val_accuracy: 0.6568 - val_recall: 0.6818 - val_precision: 0.5976
# Epoch 3/15
# 12/12 [==============================] - 18s 2s/step - loss: 5.7336 - accuracy: 0.5604 - recall: 0.5312 - precision: 0.5496 - val_loss: 1.3416 - val_accuracy: 0.7114 - val_recall: 0.6136 - val_precision: 0.6667
# Epoch 4/15
# 12/12 [==============================] - 18s 2s/step - loss: 5.9958 - accuracy: 0.5813 - recall: 0.5458 - precision: 0.5574 - val_loss: 1.3875 - val_accuracy: 0.6864 - val_recall: 0.6977 - val_precision: 0.6409
# Epoch 5/15
# 12/12 [==============================] - 19s 2s/step - loss: 5.4090 - accuracy: 0.5935 - recall: 0.5565 - precision: 0.5766 - val_loss: 1.3658 - val_accuracy: 0.7205 - val_recall: 0.7182 - val_precision: 0.7007
# Epoch 6/15
# 12/12 [==============================] - 18s 2s/step - loss: 5.9399 - accuracy: 0.5917 - recall: 0.5417 - precision: 0.5474 - val_loss: 1.5348 - val_accuracy: 0.7182 - val_recall: 0.7500 - val_precision: 0.6875
# Epoch 7/15
# 12/12 [==============================] - 18s 2s/step - loss: 4.6679 - accuracy: 0.6542 - recall: 0.6354 - precision: 0.6289 - val_loss: 1.4698 - val_accuracy: 0.7205 - val_recall: 0.7182 - val_precision: 0.7101
# Epoch 8/15
# 12/12 [==============================] - 18s 2s/step - loss: 5.0306 - accuracy: 0.6292 - recall: 0.5813 - precision: 0.5800 - val_loss: 1.5110 - val_accuracy: 0.7227 - val_recall: 0.6977 - val_precision: 0.7241
# Epoch 9/15
# 12/12 [==============================] - 18s 2s/step - loss: 5.2421 - accuracy: 0.5917 - recall: 0.5562 - precision: 0.5705 - val_loss: 1.5743 - val_accuracy: 0.7182 - val_recall: 0.7250 - val_precision: 0.6996
# Epoch 10/15
# 12/12 [==============================] - 19s 2s/step - loss: 4.2986 - accuracy: 0.6479 - recall: 0.6167 - precision: 0.6218 - val_loss: 1.6045 - val_accuracy: 0.7250 - val_recall: 0.7364 - val_precision: 0.7121
# Epoch 11/15
# 12/12 [==============================] - 24s 2s/step - loss: 5.0571 - accuracy: 0.6130 - recall: 0.5804 - precision: 0.5894 - val_loss: 1.6878 - val_accuracy: 0.7273 - val_recall: 0.7841 - val_precision: 0.6984
# Epoch 12/15
# 12/12 [==============================] - 22s 2s/step - loss: 4.9289 - accuracy: 0.6042 - recall: 0.5917 - precision: 0.5796 - val_loss: 1.6617 - val_accuracy: 0.7250 - val_recall: 0.7614 - val_precision: 0.6965
# Epoch 13/15
# 12/12 [==============================] - 25s 2s/step - loss: 4.6364 - accuracy: 0.6333 - recall: 0.6313 - precision: 0.6084 - val_loss: 1.6369 - val_accuracy: 0.7227 - val_recall: 0.7091 - val_precision: 0.7222
# Epoch 14/15
# 12/12 [==============================] - 26s 2s/step - loss: 4.1044 - accuracy: 0.6729 - recall: 0.5813 - precision: 0.6327 - val_loss: 1.6848 - val_accuracy: 0.7205 - val_recall: 0.7591 - val_precision: 0.6973
# Epoch 15/15
# 12/12 [==============================] - 28s 2s/step - loss: 3.8823 - accuracy: 0.6583 - recall: 0.6396 - precision: 0.6165 - val_loss: 1.8425 - val_accuracy: 0.7341 - val_recall: 0.7682 - val_precision: 0.7101

# %% [markdown]
# #### Evaluate Model

# %%
show_history_plot(history_Inception.history)

# %%
evaluation_matrix(Inception_model)
# Out:
#              Loss       Accuracy
# ----------------------------------
# Train        1.94738    0.71591
# Validation   1.83831    0.73409
# Test         2.04462    0.76364

# %%
show_conf_matrix(Inception_model)

# %%
Inception_model.save('LeukInception.h5')
# Out:
# /home/the_architect/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## EfficientNet

# %% [markdown]
# #### Train Model
